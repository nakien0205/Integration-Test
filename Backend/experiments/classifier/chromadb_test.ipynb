# %%
import chromadb
import pandas as pd

# Read the processed data
data = pd.read_csv('processed_data.csv')

client = chromadb.Client()
# Create a table to store data
collection = client.get_or_create_collection('Test')

# %%
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  New 15.6 inches Compatible with ROG Strix GL50...
# 1           1  Li-ion 800mAh Battery for FinePix F100fd, Fine...
# 2           2  Killer E3100 USB-C 3.1 to RJ-45 2.5Gbps Ethern...
# 3           3  Cameron-Sino Replacement Battery for Panasonic...
# 4           4  MightySkins Skin Compatible with HP Pavilion x...
#
#           brand                                        description  \
# 0       Generic  New Item. Direct form Original Factory. Compat...
# 1          GAXI  Cameron Sino created equal or higher capacity ...
# 2        Killer  Killer E3100 USB-C 3.1 to RJ-45 2.5Gbps Ethern...
# 3  Cameron-Sino  Cameron-Sino Replacement Battery for Panasonic...
# 4  MIGHTY SKINS  Give your HP Pavilion x360 - 11t Touch Laptop ...
#
#   initial_price final_price currency  \
# 0          68.3        68.3      USD
# 1           NaN         NaN      USD
# 2         48.61       48.61      USD
# 3           NaN         NaN      USD
# 4           NaN         NaN      USD
#
#                                         availability reviews_count  \
# 0                                           In Stock             0
# 1  Currently unavailable. We don't know when or i...             0
# 2                Only 11 left in stock - order soon.           108
# 3                                                NaN             0
# 4  Currently unavailable. We don't know when or i...             0
#
#   images_count  ... discount                     manufacturer  \
# 0            4  ...      NaN                          Generic
# 1            4  ...      NaN  Cameron Sino Technology Limited
# 2            5  ...      NaN                           Killer
# 3            5  ...      NaN                     Cameron-Sino
# 4            3  ...      NaN                      MightySkins
#
#                                             delivery  \
# 0  ["FREE delivery July 8 - 10. ","Or fastest del...
# 1                                                NaN
# 2  ["FREE delivery Wednesday, July 16. Order with...
# 3                                                NaN
# 4                                                NaN
#
#                              buybox_prices parent_asin is_available  \
# 0   {"final_price":68.3,"unit_price":null}  B07DH6VZB3         True
# 1                      {"unit_price":null}  B07ZQC3918        False
# 2  {"final_price":48.61,"unit_price":null}  B08HNJC3R8         True
# 3                      {"unit_price":null}  B07VSNN7XX        False
# 4                      {"unit_price":null}  B01BLSXRFY        False
#
#                                               images  \
# 0  ["https://m.media-amazon.com/images/I/61EhnSIM...
# 1  ["https://m.media-amazon.com/images/I/41N-GtE+...
# 2  ["https://m.media-amazon.com/images/I/51mUbLqP...
# 3  ["https://m.media-amazon.com/images/I/415EF5Tz...
# 4  ["https://m.media-amazon.com/images/I/51HaEk3I...
#
#                                      product_details max_quantity_available  \
# 0  [{"type":"Package Dimensions","value":"12 x 8 ...                   30.0
# 1  [{"type":"Product Dimensions","value":"1 x 1 x...                    NaN
# 2  [{"type":"Brand","value":"Killer"},{"type":"It...                   11.0
# 3  [{"type":"Product Dimensions","value":"3.31 x ...                    NaN
# 4  [{"type":"Product Dimensions","value":"16 x 1 ...                    NaN
#
#                return_policy
# 0  30-day refund/replacement
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 24 columns]

# %%
# Enhanced prompt template using data from processed_data.csv
def create_product_prompt(row):
    """
    Create a comprehensive product prompt for LLM using all available data
    """
    import pandas as pd
    
    # Helper function to safely get values and handle NaN
    def safe_get(key, default=None):
        value = row.get(key, default)
        if pd.isna(value) or value == '' or value == 'nan':
            return default
        return value
    
    # Basic product information
    title = safe_get('title', 'Product name not available')
    brand = safe_get('brand', 'Brand not specified')
    description = safe_get('description', 'No description available')
    
    # Pricing information
    initial_price = safe_get('initial_price')
    final_price = safe_get('final_price')
    currency = safe_get('currency', 'USD')
    discount = safe_get('discount')
    
    # Create price text
    if final_price:
        try:
            final_price = float(final_price)
            if initial_price:
                initial_price = float(initial_price)
                if initial_price != final_price:
                    price_text = f"The current price is {final_price} {currency}, originally priced at {initial_price} {currency}"
                    if discount:
                        price_text += f" (discount: {discount})"
                else:
                    price_text = f"The price is {final_price} {currency}"
            else:
                price_text = f"The price is {final_price} {currency}"
        except (ValueError, TypeError):
            price_text = "The price is not available - please contact the seller"
    else:
        price_text = "The price is not available - please contact the seller"
    
    # Availability and stock information
    availability = safe_get('availability', 'Availability unknown')
    is_available = safe_get('is_available', False)
    max_quantity = safe_get('max_quantity_available')
    
    availability_text = f"Availability: {availability}"
    if max_quantity:
        try:
            max_quantity = float(max_quantity)
            availability_text += f" (Maximum quantity available: {int(max_quantity)})"
        except (ValueError, TypeError):
            pass
    
    # Product specifications
    item_weight = safe_get('item_weight')
    product_dimensions = safe_get('product_dimensions')
    
    specs_text = ""
    if item_weight:
        specs_text += f"Item weight: {item_weight}. "
    if product_dimensions:
        specs_text += f"Product dimensions: {product_dimensions}. "
    
    # Reviews and ratings
    rating = safe_get('rating')
    reviews_count = safe_get('reviews_count', 0)
    
    try:
        reviews_count = int(float(reviews_count)) if reviews_count else 0
        rating = float(rating) if rating else None
    except (ValueError, TypeError):
        reviews_count = 0
        rating = None
    
    if rating and reviews_count:
        reviews_text = f"Customer rating: {rating} out of 5 stars based on {reviews_count} reviews"
    elif reviews_count > 0:
        reviews_text = f"Based on {reviews_count} customer reviews"
    else:
        reviews_text = "No customer reviews available yet"
    
    # Delivery information
    delivery = safe_get('delivery')
    delivery_text = f"Delivery: {delivery}" if delivery else "Delivery information not specified"
    
    # Return policy
    return_policy = safe_get('return_policy')
    return_text = f"Return policy: {return_policy}" if return_policy else "Return policy not specified"
    
    # Manufacturer information
    manufacturer = safe_get('manufacturer')
    manufacturer_text = f"Manufactured by {manufacturer}" if manufacturer else ""
    
    # Images information
    images_count = safe_get('images_count', 0)
    try:
        images_count = int(float(images_count)) if images_count else 0
    except (ValueError, TypeError):
        images_count = 0
    
    images_text = f"Product has {images_count} images available" if images_count > 0 else "No product images available"
    
    # Construct the comprehensive prompt
    prompt = f"""
Product Information:
{title} is sold on Amazon from the brand {brand}.

Description:
{description}

Pricing:
{price_text}

Availability:
{availability_text}

Customer Reviews:
{reviews_text}

Product Specifications:
{specs_text if specs_text else 'Product specifications not available'}

Shipping & Returns:
{delivery_text}
{return_text}

Additional Information:
{manufacturer_text}
{images_text}
"""
    
    return prompt.strip()

# Example usage with a sample row
sample_prompt = create_product_prompt(data.iloc[0])
print("Sample prompt for first product:")
print("="*50)
print(sample_prompt)
# Out:
# Sample prompt for first product:
# ==================================================
# Product Information:
# New 15.6 inches Compatible with ROG Strix GL503VM-DB74 Gaming Laptop IPS FHD 1080P Laptop LED LCD Replacement Screen is sold on Amazon from the brand Generic.
#
# Description:
# New Item. Direct form Original Factory. Compatibility Guaranteed. Pixels Policy in Accordance with ISO Regulation. Fullcom – We export high quality LCD screens throughout more than 80 countries all over the world. With our longer than 15 years LCD-business experience, we have the confidence to provide you several advantages make your business successfully.First of all, we have strong support directly from original manufacturers, we can offer you stable quality LCD at reasonable price. Secondly, we have professional purchasing team locates in Taiwan. We deem to search for reliable quality screens. Most importantly, in order to keep quality stable, we also test screens 100% in order to confirm all screens must approve by ISO-13406. To work in this way, we hope to set up a win-win business with all of our customers. Of course, we usually have more than 500 kinds of popular screens in stock and size from 7” to 23.8”. If you have any LCD screen or larger quantity demand, please feel free to contact our customer service.It is my pleasure to serve and work with you. Please match your original screen's screen model, BACKLIGHT TYPE, SIZE, CONNECTOR TYPE, and RESOLUTION before you purchase this item, because some laptop models come with more than one type of screens. Please note that we might ship compatible models based on stock. For any unsure situation, please contact us. If you are unsure about which screen fits your laptop, please don’t hesitate to contact us. We will be glad to help you find a correct item. All products we provide are compatible based on our test. Depending on our stock, model name and outline size may be slightly different.INSTALLATION ADVICEPlease disconnect your laptop power and remove the battery before installation to avoid possible damage to the electrical components.
#
# Pricing:
# The price is 68.3 USD
#
# Availability:
# Availability: In Stock (Maximum quantity available: 30)
#
# Customer Reviews:
# No customer reviews available yet
#
# Product Specifications:
# Item weight: 9.9 ounces. Product dimensions: 12 x 8 x 1.2 inches.
#
# Shipping & Returns:
# Delivery: ["FREE delivery July 8 - 10. ","Or fastest delivery Wednesday, July 9. "]
# Return policy: 30-day refund/replacement
#
# Additional Information:
# Manufactured by Generic
# Product has 4 images available

# %%
import ollama
from tqdm._tqdm_notebook import tqdm

embeddings = []

print("Creating prompts for all products...")
for i in tqdm(range(50)):
    prompt = data.title[i]

    embed = ollama.embed(
        model='llama3.2:1B',
        input=prompt
    )

    embeddings.append((i, embed))
# Out:
# Creating prompts for all products...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# Convert embeddings to the right format (remove index from tuples)
embed_vectors = []
for i in range(50):
    embed_vectors.append(embeddings[i][1]['embeddings'])

ids = [data.iloc[i, 1] for i in range(50)]

# Create proper serializable metadata dictionaries
metadatas = []
for i in range(50):
    # Convert the row to a dictionary and keep only string/numeric values
    row_dict = data.iloc[i].to_dict()
    # Add the source title as a special field
    row_dict["source"] = f"Title: {data.iloc[i]['title']}"
    metadatas.append(row_dict)

# Add documents to collection
collection.add(
    ids=ids,
    embeddings=[embed_vectors[i][0] for i in range(50)],
    metadatas=metadatas
)

# %%
from chromadb.utils.embedding_functions import OllamaEmbeddingFunction

llama_embeder = OllamaEmbeddingFunction(model_name='llama3.2:1B')
res_list = []

input_query = '''
ROG gaming laptop from Generic.
'''


q_embed = llama_embeder([input_query])

res_list.append(collection.query(
    query_embeddings=q_embed,
    n_results=1
))

res_list
# Out:
# [{'ids': [['Recorder Battery Replacement for Casio Exilim EX-S6SR,Exilim EX-S8,Exilim EX-S8BE,Exilim EX-S8BK,Exilim EX-S8PE,Exilim EX-S8PK NP-82']],
#   'embeddings': None,
#   'documents': [[None]],
#   'uris': None,
#   'included': ['metadatas', 'documents', 'distances'],
#   'data': None,
#   'metadatas': [[{'availability': "Currently unavailable. We don't know when or if this item will be back in stock.",
#      'currency': 'USD',
#      'parent_asin': 'B0B616NHFB',
#      'url': 'https://www.amazon.com/Recorder-Battery-Replacement-EX-S6SR-EX-S8BE/dp/B0B616NHFB?th=1&psc=1&language=en_US&currency=USD',
#      'images_count': '5',
#      'title': 'Recorder Battery Replacement for Casio Exilim EX-S6SR,Exilim EX-S8,Exilim EX-S8BE,Exilim EX-S8BK,Exilim EX-S8PE,Exilim EX-S8PK NP-82',
#      'reviews_count': '0',
#      'manufacturer': 'Willump',
#      'item_weight': '1.41 ounces',
#      'source': 'Title: Recorder Battery Replacement for Casio Exilim EX-S6SR,Exilim EX-S8,Exilim EX-S8BE,Exilim EX-S8BK,Exilim EX-S8PE,Exilim EX-S8PK NP-82',
#      'description': 'Stable performance. Designed Specifically for you. The products has been passed CE Certification. Part No.: Casio NP-82Fit Model.: Casio Exilim EX-S6SR,Exilim EX-S8,Exilim EX-S8BE,Exilim EX-S8BK,Exilim EX-S8PE,Exilim EX-S8PKBattery Type: Li-ionVolts: 3.7VCapacity: 660mAh / 2.44Wh Dimension: 40.00 x 31.10 x 5.90mmCondition: 100% Brand NEW Warranty: 1 Year Replacement Warranty',
#      'is_available': 'False',
#      'buybox_prices': '{"unit_price":null}',
#      'Unnamed: 0': 41,
#      'product_dimensions': '1.57 x 1.22 x 0.23 inches',
#      'brand': 'Willump',
#      'product_details': '[{"type":"Product Dimensions","value":"1.57 x 1.22 x 0.23 inches"},{"type":"Item Weight","value":"1.41 ounces"},{"type":"ASIN","value":"B0B616NHFB"},{"type":"Date First Available","value":"July 7, 2022"},{"type":"Manufacturer","value":"Willump"},{"type":"Item dimensions L x W x H","value":"1.57 x 1.22 x 0.23 inches"},{"type":"Item Weight","value":"40 Grams"},{"type":"Manufacturer","value":"Willump"}]',
#      'rating': '0.0',
#      'images': '["https://m.media-amazon.com/images/I/51R06VgjmRL._AC_.jpg","https://m.media-amazon.com/images/I/51JqXGw15bL._AC_.jpg","https://m.media-amazon.com/images/I/41Pe02kabJL._AC_.jpg","https://m.media-amazon.com/images/I/417hvwBQrdL._AC_.jpg","https://m.media-amazon.com/images/I/51U4M5iG1YL._AC_.jpg"]'}]],
#   'distances': [[1.0860939025878906]]}]

# %% [markdown]
# # Stop here, the code above is having a problem

# %%
import ollama
from tqdm._tqdm_notebook import tqdm

eval_list = []

for i in tqdm(range(100)):
  instruction_prompt = f'''
  You are a helpful chatbot that gives a concise and short answer.
  Use only the following pieces of context to answer the question. Don't make up any new information:
  {res_list[i]['metadatas'][0][0]['text'], res_list[i]['metadatas'][0][1]['text']}
  '''

  eval_prompt = '''
  You are an answer evaluator. Compare the correct answer with the predicted answer and determine if they match.
  The predicted answer must be CONSISTENT and CLEAR throughout - contradictory statements should be marked as incorrect.

  You can ONLY output:
  - "1" if the predicted answer is correct, consistent, and substantially matches the correct answer
  - "0" if the predicted answer is incorrect, contradictory, unclear, or does not match the correct answer

  Do not provide any explanation, just output the number.
  '''

  answer = ollama.chat(
      model='llama3.2:1B',
      messages=[
        {'role': 'system', 'content': instruction_prompt},
        {'role': 'user', 'content': test['test']['question'][i]},
      ]
  )

  # print the response from the chatbot in real-time
  # print('Chatbot response:')
  # print(answer['message']['content'])

  # Get the correct answer from your test dataset
  correct_answer = test['test']['answer'][i]  # Adjust index as needed
  predicted_answer = answer['message']['content']

  evaluation_input = f"Correct answer: {correct_answer}\nPredicted answer: {predicted_answer}"

  evaluation = ollama.chat(
      model='llama3.2:1B',
      messages=[
        {'role': 'system', 'content': eval_prompt},
        {'role': 'user', 'content': evaluation_input},
      ]
  )


  evaluation_score = evaluation['message']['content'].strip()
  eval_list.append(int(evaluation_score))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 10
#       4 eval_list = []
#       6 for i in tqdm(range(100)):
#       7   instruction_prompt = f'''
#       8   You are a helpful chatbot that gives a concise and short answer.
#       9   Use only the following pieces of context to answer the question. Don't make up any new information:
# ---> 10   {res_list[i]['metadatas'][0][0]['text'], res_list[i]['metadatas'][0][1]['text']}
#      11   '''
#      13   eval_prompt = '''
#      14   You are an answer evaluator. Compare the correct answer with the predicted answer and determine if they match.
#      15   The predicted answer must be CONSISTENT and CLEAR throughout - contradictory statements should be marked as incorrect.
#    (...)     21   Do not provide any explanation, just output the number.
#      22   '''
#      24   answer = ollama.chat(
#      25       model='llama3.2:1B',
#      26       messages=[
#    (...)     29       ]
#      30   )
#
# KeyError: 'text'

# %%
correct = 0
for i in eval_list:
    if i == 1:
        correct += 1
correct
# Out:
# 97

# %%
test['test']['answer'][3]
# Out:
# '18 months'
